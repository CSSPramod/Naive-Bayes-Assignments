# %%
# Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# import Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
salary_train=pd.read_csv('/content/drive/MyDrive/DS Data Sets/Naive Bayes/SalaryData_Train.csv.crdownload')
salary_test=pd.read_csv('/content/drive/MyDrive/DS Data Sets/Naive Bayes/SalaryData_Test.csv')

# %%
salary_train
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 25180   19            Private   Some-college           10
# 25181   33   Self-emp-not-inc        HS-grad            9
# 25182   32            Private        HS-grad            9
# 25183   52            Private        HS-grad            9
# 25184   36            Private   Some-college           10
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 25180        Never-married        Tech-support   Not-in-family   White
# 25181   Married-civ-spouse        Craft-repair         Husband   White
# 25182             Divorced       Other-service       Unmarried   White
# 25183             Divorced    Transport-moving   Not-in-family   White
# 25184            Separated        Other-servic             NaN     NaN
#
#            sex  capitalgain  capitalloss  hoursperweek          native  Salary
# 0         Male       2174.0          0.0          40.0   United-States   <=50K
# 1         Male          0.0          0.0          13.0   United-States   <=50K
# 2         Male          0.0          0.0          40.0   United-States   <=50K
# 3         Male          0.0          0.0          40.0   United-States   <=50K
# 4       Female          0.0          0.0          40.0            Cuba   <=50K
# ...        ...          ...          ...           ...             ...     ...
# 25180   Female          0.0          0.0          25.0   United-States   <=50K
# 25181     Male          0.0          0.0          40.0   United-States   <=50K
# 25182   Female          0.0          0.0          80.0   United-States   <=50K
# 25183     Male          0.0          0.0          40.0   United-States   <=50K
# 25184      NaN          NaN          NaN           NaN             NaN     NaN
#
# [25185 rows x 14 columns]

# %%
salary_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
# EDA

# %%
salary_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25185 entries, 0 to 25184
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            25185 non-null  int64
#  1   workclass      25185 non-null  object
#  2   education      25185 non-null  object
#  3   educationno    25185 non-null  int64
#  4   maritalstatus  25185 non-null  object
#  5   occupation     25185 non-null  object
#  6   relationship   25184 non-null  object
#  7   race           25184 non-null  object
#  8   sex            25184 non-null  object
#  9   capitalgain    25184 non-null  float64
#  10  capitalloss    25184 non-null  float64
#  11  hoursperweek   25184 non-null  float64
#  12  native         25184 non-null  object
#  13  Salary         25184 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 2.7+ MB

# %%
salary_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
salary_train['workclass']=le.fit_transform(salary_train['workclass'])
salary_train['education']=le.fit_transform(salary_train['education'])
salary_train['maritalstatus']=le.fit_transform(salary_train['maritalstatus'])
salary_train['occupation']=le.fit_transform(salary_train['occupation'])
salary_train['relationship']=le.fit_transform(salary_train['relationship'])
salary_train['race']=le.fit_transform(salary_train['race'])
salary_train['sex']=le.fit_transform(salary_train['sex'])
salary_train['native']=le.fit_transform(salary_train['native'])

# %%
salary_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2          10
# ...    ...        ...        ...          ...            ...         ...
# 25180   19          2         15           10              4          13
# 25181   33          4         11            9              2           2
# 25182   32          2         11            9              0           8
# 25183   52          2         11            9              0          14
# 25184   36          2         15           10              5           7
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 1     4    1       2174.0          0.0          40.0
# 1                 0     4    1          0.0          0.0          13.0
# 2                 1     4    1          0.0          0.0          40.0
# 3                 0     2    1          0.0          0.0          40.0
# 4                 5     2    0          0.0          0.0          40.0
# ...             ...   ...  ...          ...          ...           ...
# 25180             1     4    0          0.0          0.0          25.0
# 25181             0     4    1          0.0          0.0          40.0
# 25182             4     4    0          0.0          0.0          80.0
# 25183             1     4    1          0.0          0.0          40.0
# 25184             6     5    2          NaN          NaN           NaN
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37   <=50K
# 3          37   <=50K
# 4           4   <=50K
# ...       ...     ...
# 25180      37   <=50K
# 25181      37   <=50K
# 25182      37   <=50K
# 25183      37   <=50K
# 25184      40     NaN
#
# [25185 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
salary_test['workclass']=le.fit_transform(salary_test['workclass'])
salary_test['education']=le.fit_transform(salary_test['education'])
salary_test['maritalstatus']=le.fit_transform(salary_test['maritalstatus'])
salary_test['occupation']=le.fit_transform(salary_test['occupation'])
salary_test['relationship']=le.fit_transform(salary_test['relationship'])
salary_test['race']=le.fit_transform(salary_test['race'])
salary_test['sex']=le.fit_transform(salary_test['sex'])
salary_test['native']=le.fit_transform(salary_test['native'])

# %%
salary_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 3     2    1            0            0            40
# 1                 0     4    1            0            0            50
# 2                 0     4    1            0            0            40
# 3                 0     2    1         7688            0            40
# 4                 1     4    1            0            0            30
# ...             ...   ...  ...          ...          ...           ...
# 15055             3     4    1            0            0            40
# 15056             1     4    0            0            0            36
# 15057             0     4    1            0            0            50
# 15058             3     1    1         5455            0            40
# 15059             0     4    1            0            0            60
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37    >50K
# 3          37    >50K
# 4          37   <=50K
# ...       ...     ...
# 15055      37   <=50K
# 15056      37   <=50K
# 15057      37   <=50K
# 15058      37   <=50K
# 15059      37    >50K
#
# [15060 rows x 14 columns]

# %%
salary_trainx=salary_train.iloc[:,0:13]
salary_trainy=salary_train.iloc[:,-1]
salary_testx=salary_test.iloc[:,0:13]
salary_testy=salary_test.iloc[:,-1]

# %%
# Model Training

# %%
# train Gaussian Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB

# %%
classifier_gb=GaussianNB()

# %%
# check for null values
print(salary_trainx.isnull().sum())
print(salary_trainy.isnull().sum())

# %%
 # Drop rows with null values
 salary_trainx.dropna(inplace=True)
 salary_trainy.dropna(inplace=True)

# %%
# Reset the indices of DataFrame
salary_trainx.reset_index(drop=True,inplace=True)
salary_trainy.reset_index(drop=True,inplace=True )

# %%
classifier_gb.fit(salary_trainx,salary_trainy)
# Out:
# GaussianNB()

# %%
# Model Predictions

# %%
y_pred=classifier_gb.predict(salary_testx)
y_pred
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
# Accuracy Score
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(salary_testy, y_pred))
# Out:
# 0.7960159362549801

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(salary_testy,y_pred)
print(cm)
# Out:
# [[10773   587]
#  [ 2485  1215]]

# %%
# Classification report
from sklearn.metrics import classification_report

# %%
print(classification_report(salary_testy,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.81      0.95      0.88     11360
#         >50K       0.67      0.33      0.44      3700
#
#     accuracy                           0.80     15060
#    macro avg       0.74      0.64      0.66     15060
# weighted avg       0.78      0.80      0.77     15060
